# %% [markdown]
# # BHSM v1.3F - State Ontology
#
# This notebook records the BHSM state ontology ledger. It clarifies that internal modes and virtual dressing contributions are not automatically new observable particles. It does not prove the full `H_T` theorem and does not change frozen predictions.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from state_ontology import state_ontology_report

report = state_ontology_report()
report.title, report.theorem_complete

# %% [markdown]
# ## Category Counts

# %%
report.category_counts

# %% [markdown]
# ## Rules R1-R8

# %%
[
    {
        "id": rule.id,
        "category": rule.category.value if rule.category else "OPEN",
        "statement": rule.statement,
    }
    for rule in report.ledger.rules
]

# %% [markdown]
# ## Example Classifications

# %%
classifications = {item.state_id: item for item in report.ledger.classifications}
[
    {
        "state": state.id,
        "name": state.name,
        "category": classifications[state.id].category.value,
        "observable_particle": classifications[state.id].observable_particle,
        "virtual_or_dressing": classifications[state.id].virtual_or_dressing,
        "forbidden_extra_light": classifications[state.id].forbidden_extra_light,
    }
    for state in report.ledger.states
]

# %% [markdown]
# ## Claim Boundary
#
# BHSM v1.3F clarifies that internal modes and virtual dressing contributions are not automatically new observable particles. Extra observable light states remain forbidden unless identified experimentally or lifted/screened by the `H_T`/scalar-sector mechanisms.
