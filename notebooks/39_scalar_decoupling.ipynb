# %% [markdown]
# # BHSM v1.5 -- Scalar/Topographic Decoupling Scaffold
#
# This notebook records the sufficient scalar/topographic decoupling conditions. It does not prove the full action-level scalar theorem.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from scalar_decoupling_theorem import build_scalar_decoupling_theorem_report
report = build_scalar_decoupling_theorem_report()
report.status, report.theorem_complete, len(report.forbidden_or_open_current_modes)

# %% [markdown]
# ## Current Inventory

# %%
[(row['mode_id'], row['category'], row['status'], row['allowed'], row['conditional']) for row in report.scalar_inventory['current_inventory']]

# %% [markdown]
# ## Screening Conditions

# %%
[(row['id'], row['name'], row['status']) for row in report.screening['conditions']]
