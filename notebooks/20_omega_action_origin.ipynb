# %% [markdown]
# # BHSM v1.2 - Omega Action-Origin Scaffold
#
# This notebook audits the symbolic boundary functional used to recover the charged-sector boundary operators. It does not change the frozen v1.0/v1.1 prediction packages.

# %% [markdown]
# Operational targets:
#
# - $\Omega_\ell=-q+2j=3$
# - $\Omega_u=q-2j=6$
# - $\Omega_d=q+4j=12$

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))

from omega_derivation import build_omega_action_origin_report

report = build_omega_action_origin_report()
report.theorem_complete

# %%
report.coefficient_status_table

# %%
report.recovered_mode_ledger

# %%
report.dependency_graph

# %% [markdown]
# What v1.2 proves: the omega coefficients follow from the explicit symbolic sector boundary functional.
#
# What v1.2 does not prove: the full twisted Dirac/bundle action uniquely generates that functional.
#
# Limitation: `DERIVED_FROM_BOUNDARY_FUNCTIONAL` means derived inside the explicit symbolic boundary functional only. The full variation/spectrum of the Berger-Hopf internal action remains open.
