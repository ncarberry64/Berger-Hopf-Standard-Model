# %% [markdown]
# # BHSM v1.6 Scalar/Topographic Screening Proof Scaffold
#
# This notebook records the derivative-screening, curvature-screening, matter-coupling, and fifth-force exclusion scaffold. It does not claim a full scalar-screening theorem.

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root / 'src'))

from fifth_force_exclusion import build_scalar_screening_proof_report

report = build_scalar_screening_proof_report()
report.status, report.theorem_complete

# %%
[(row.id, row.coupling_operator, row.status) for row in report.derivative_conditions]

# %%
[(row.id, row.coupling_operator, row.flat_limit_suppresses, row.status) for row in report.curvature_conditions]

# %%
[(row.mode_id, row.channel, row.status) for row in report.matter_coupling_audit]

# %% [markdown]
# ## Limitation
#
# The scaffold excludes fifth-force channels conditionally under derivative/curvature/virtual/lift assumptions. The complete scalar/topographic action proof remains open.
