# %% [markdown]
# # BHSM v2.8 Curvature Remainder Formula and Bound
#
# This notebook records the v2.8 formula/bound audit without changing frozen predictions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').joinpath('src').resolve()))
from curvature_remainder_formula_decision import build_curvature_remainder_formula_decision
build_curvature_remainder_formula_decision()

# %% [markdown]
# Final result: `STILL_BLOCKED_BY_SINGLE_NAMED_THEOREM_GAP`.
#
# Final classification: `REMAINDER_OPEN`.
#
# Exact remaining gap: `COMPLETE_BHSM_BUNDLE_CONNECTION_CURVATURE_FORMULA_GAP`.
