# %% [markdown]
# # BHSM v2.7 Bundle Curvature Remainder
#
# This notebook records the curvature-remainder audit without changing frozen BHSM predictions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').joinpath('src').resolve()))
from curvature_remainder_closure_decision import build_curvature_remainder_closure_decision
build_curvature_remainder_closure_decision()

# %% [markdown]
# Final result: `STILL_BLOCKED_BY_SINGLE_NAMED_THEOREM_GAP`.
#
# Remainder classification: `REMAINDER_OPEN`.
#
# Exact remaining gap: `BUNDLE_CURVATURE_REMAINDER_FORMULA_AND_BOUND_GAP`.
