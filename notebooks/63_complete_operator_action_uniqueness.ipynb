# %% [markdown]
# # BHSM v2.13 Complete Operator Action-Uniqueness
#
# Executable audit for the v2.13 action-uniqueness closure.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'src'))
from complete_operator_action_uniqueness_decision import build_complete_operator_action_uniqueness_decision
from operator_alternative_term_audit import build_operator_alternative_term_audit_report
from complete_twisted_dirac_operator import build_complete_twisted_dirac_operator_report
from full_ht_theorem_closure import build_full_ht_theorem_closure_report

# %%
build_complete_operator_action_uniqueness_decision()

# %%
[(row.term_id, row.classification, row.equivalent_to) for row in build_operator_alternative_term_audit_report().alternatives]

# %%
operator = build_complete_twisted_dirac_operator_report()
ht = build_full_ht_theorem_closure_report()
(operator.status, operator.theorem_complete, ht.final_result, ht.single_named_gap, ht.recommended_next_branch)

# %% [markdown]
# ## Limitation
#
# This closes complete-operator action uniqueness. It does not prove the full H_T theorem; projector commutator control remains next.
