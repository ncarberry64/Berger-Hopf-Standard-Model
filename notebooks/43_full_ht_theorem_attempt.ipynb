# %% [markdown]
# # BHSM Gate 1 — Full H_T Theorem Closure Attempt
#
# This notebook records the final-closure H_T theorem attempt. It does not claim the full theorem is proven.

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root / 'src'))
from full_ht_theorem import build_full_ht_theorem_report
report = build_full_ht_theorem_report()
report.status, report.theorem_complete, report.formal_kernel_coordinates

# %%
report.remaining_open_nodes

# %% [markdown]
# The corrected finite/semi-analytic thresholds are strong, but the infinite-basis complement, full operator domain, and topological index theorem remain open.
