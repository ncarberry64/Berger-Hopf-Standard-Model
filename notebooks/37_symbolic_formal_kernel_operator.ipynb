# %% [markdown]
# # BHSM v1.3O -- Symbolic Formal-Kernel Operator
#
# This notebook records the coordinate-free formal-kernel scaffold for `DIRAC_PROXY_LEVEL_2_FORMAL_KERNEL`. It is a scaffold and does not prove the full `(H_T)` theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from coordinate_free_subspace import formal_kernel_subspace, coordinate_free_projector, basis_realization_scan
from formal_kernel_symbolic_operator import symbolic_operator_terms, symbolic_complement_bound

# %% [markdown]
# ## Coordinate-Free Protected Subspace
#
# `K_formal = span{|ell,0,0,q=0,chi=-1>, |u,0,0,q=0,chi=-1>, |d,0,0,q=0,chi=-1>}` and `H_perp = K_formal^perp`.

# %%
formal_kernel_subspace()
coordinate_free_projector()

# %% [markdown]
# ## Basis Realization
#
# The sector-major formula is `M(k_max)=sum(floor(k/2)+1)`, with `ell=0`, `u=2M`, and `d=4M`.

# %%
[(row.k_max, row.realized_coordinates, row.matches_current_basis) for row in basis_realization_scan((4, 6, 8, 10, 12))]

# %% [markdown]
# ## Symbolic Operator Terms

# %%
[(term.id, term.classification, term.vanishes_on_k_formal, term.preserves_k_formal, term.status) for term in symbolic_operator_terms()]

# %% [markdown]
# ## Complement Bound
#
# The bound remains conditional: if the coordinate-free split, complement lower bound, relative sector-coupling bound, and PSD profile condition hold in the full operator, then the `(H_T)` complement bound follows.

# %%
symbolic_complement_bound()
