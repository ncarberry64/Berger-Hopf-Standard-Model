# %% [markdown]
# # BHSM v2.15 Projector Graph-Domain Stability
#
# This notebook records the v2.15 audit for the formal complement projector. It does not change frozen BHSM predictions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..', 'src').resolve()))

from interacting_graph_domain import build_interacting_graph_domain_report
from projector_domain_invariance import build_projector_domain_invariance_report
from projector_graph_norm_control import build_projector_graph_norm_control_report
from projector_domain_closure_decision import build_projector_domain_closure_decision

# %%
domain = build_interacting_graph_domain_report()
invariance = build_projector_domain_invariance_report()
graph_norm = build_projector_graph_norm_control_report()
decision = build_projector_domain_closure_decision()

domain, graph_norm, decision

# %% [markdown]
# The intended status is `PROJECTOR_GRAPH_DOMAIN_STABILITY_CLOSED`. The full `H_T` theorem remains blocked downstream unless lower-bound transfer, index theorem, and mirror exclusion are also closed.
