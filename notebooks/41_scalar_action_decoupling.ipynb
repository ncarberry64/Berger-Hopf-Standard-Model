# %% [markdown]
# # BHSM v1.5 Scalar/Topographic Action-Decoupling Scaffold
#
# This notebook records the v1.5 scalar/topographic action-level scaffold. It does not claim full scalar decoupling from the complete Berger-Hopf action.

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root / 'src'))

from scalar_decoupling_proof import build_scalar_action_proof_report

report = build_scalar_action_proof_report()
report.status, report.theorem_complete, report.corrected_ht_dependency['model_level']

# %%
[(term.id, term.channel, term.status) for term in report.scalar_action_terms]

# %%
[(mode.mode_id, mode.channel, mode.on_shell_light_particle, mode.status) for mode in report.scalar_modes]

# %%
[(row.mode_id, row.effective_mass_gev, row.compton_range_m, row.status) for row in report.fifth_force_bounds]

# %% [markdown]
# ## Limitation
#
# The scaffold uses the corrected `DIRAC_PROXY_LEVEL_2_FORMAL_KERNEL` dependency for H_T-linked scalar complement lifting. The full H_T theorem and the full scalar/topographic action proof remain open.
