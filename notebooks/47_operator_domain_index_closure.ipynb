# %% [markdown]
# # BHSM v1.7 Operator-Domain and Index Closure
#
# This notebook records the operator-domain, relative-bound, index, and mirror status feeding the full `H_T` theorem. It does not change frozen predictions.

# %%
import sys
sys.path.insert(0, '../src')
from operator_domain_index_closure import build_operator_domain_index_closure_report
report = build_operator_domain_index_closure_report()
report.domain_status, report.relative_bound_status, report.index_status, report.mirror_status, report.ht_dependency_status

# %%
report.formal_kernel

# %%
[(term.term_id, term.relative_a, term.relative_b, term.below_one, term.infinite_basis_compatible) for term in report.relative_bound_report.terms]

# %% [markdown]
# ## Limitation
#
# The status remains `HT_THEOREM_BLOCKED_BY_DOMAIN`; this is not a proof of the full no-extra-light-state theorem.
