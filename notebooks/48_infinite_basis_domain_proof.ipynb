# %% [markdown]
# # BHSM v1.8 Infinite-Basis Domain and Relative-Bound Proof Attempt
#
# This notebook summarizes the v1.8 domain, relative-bound, self-adjointness, complement, and H_T bridge reports. It does not change frozen predictions.

# %%
import sys
sys.path.insert(0, '../src')
from infinite_basis_domain import build_infinite_basis_domain_report
from uniform_relative_bound import build_uniform_relative_bound_report
from self_adjoint_closure import build_self_adjoint_closure_report
from formal_complement_stability import build_formal_complement_stability_report
from ht_domain_bridge import build_ht_domain_bridge_report
domain = build_infinite_basis_domain_report()
relative = build_uniform_relative_bound_report()
self_adj = build_self_adjoint_closure_report()
comp = build_formal_complement_stability_report()
bridge = build_ht_domain_bridge_report()
(domain.status, relative.status, self_adj.status, comp.status, bridge.domain_bridge_status)

# %%
domain.formal_kernel

# %%
[(term.term_id, term.relative_a, term.relative_b, term.status, term.assumptions_proven) for term in relative.terms]

# %% [markdown]
# ## Limitation
#
# The H_T bridge is strengthened to `HT_THEOREM_CANDIDATE_STRENGTHENED`, but this is not `FULL_HT_THEOREM_PROVEN`.
