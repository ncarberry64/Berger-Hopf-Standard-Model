# %% [markdown]
# # BHSM v2.4 Complete-Operator Domain Stability
#
# Executable audit notebook for the v2.4 H_T domain-stability decision.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..', 'src').resolve()))
from complete_operator_domain_stability import build_complete_operator_domain_stability_report
from ht_domain_stability_decision import build_ht_domain_stability_decision

# %%
domain = build_complete_operator_domain_stability_report()
decision = build_ht_domain_stability_decision()
domain, decision

# %% [markdown]
# ## Claim Discipline
#
# This notebook reports conditional domain-stability bridge status only. It does not claim the full H_T theorem is proven.
