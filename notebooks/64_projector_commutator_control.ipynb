# %% [markdown]
# # BHSM v2.14 Projector Commutator Control
#
# Executable audit for projector commutator control.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'src'))
from projector_commutator_control_decision import build_projector_commutator_control_decision
from projector_operator_commutators import build_projector_operator_commutators_report
from projector_commutator_relative_bound import build_projector_commutator_relative_bound_report
from full_ht_theorem_closure import build_full_ht_theorem_closure_report

# %%
build_projector_commutator_control_decision()

# %%
[(row.term_id, row.classification, row.vanishes, row.relative_a) for row in build_projector_operator_commutators_report().rows]

# %%
build_projector_commutator_relative_bound_report()

# %%
ht = build_full_ht_theorem_closure_report()
(ht.final_result, ht.single_named_gap, ht.recommended_next_branch)

# %% [markdown]
# ## Limitation
#
# This closes projector commutator control. It does not prove projector graph-domain stability or the full H_T theorem.
