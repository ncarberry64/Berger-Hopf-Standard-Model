# %% [markdown]
# # BHSM v2.1 Perturbation Domain and Infinite-Bound Proof
#
# This notebook records the generated v2.1 perturbation closure decision. It is not a full H_T theorem proof.

# %%
import sys
sys.path.append('../src')
from perturbation_closure_decision import build_perturbation_closure_decision
report = build_perturbation_closure_decision()
report

# %% [markdown]
# Final v2.1 dependency status: `HT_THEOREM_CONDITIONAL_ON_COMPLEMENT`. Full theorem complete: `False`.
