# %% [markdown]
# # BHSM v1.3N — Formal-Kernel Action-Origin and Semi-Analytic Bound
#
# This notebook records the action/boundary/basis origin scaffold for the corrected formal-kernel projector and the semi-analytic complement-bound scaffold.
#
# Correct claim: v1.3N constrains the projector inside the BHSM scaffold; it does not prove the full `H_T` theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from formal_kernel_action_origin import build_formal_kernel_action_origin_report
from semi_analytic_complement_bound import build_semi_analytic_complement_bound, diagonal_complement_modes

action_report = build_formal_kernel_action_origin_report()
action_report.projector_derivation

# %% [markdown]
# ## Action / Boundary / Basis Rules

# %%
action_report.rules

# %% [markdown]
# ## Semi-Analytic Complement Bound

# %%
bound = build_semi_analytic_complement_bound()
bound

# %%
diagonal_complement_modes()[:5]

# %% [markdown]
# ## Limitation
#
# The coordinate derivation is finite-basis and basis-ordering-dependent. The full twisted Dirac / `H_T` theorem remains open.
