# %% [markdown]
# # CKM and PMNS Screens
# PMNS belongs to an effective neutrino extension, not the minimal Standard Model.

# %%
import numpy as np
from ckm import ckm_from_left_bases, is_unitary
from pmns import pmns_from_left_bases, pmns_is_unitary

eye = np.eye(3)
is_unitary(ckm_from_left_bases(eye, eye)), pmns_is_unitary(pmns_from_left_bases(eye, eye))
