# %% [markdown]
# # Hypercharge and Anomaly Audits
# Run from the repository root after installing dependencies.

# %%
from hypercharge import hypercharge_screen
from anomalies import anomaly_screen

hypercharge_screen(), anomaly_screen()
