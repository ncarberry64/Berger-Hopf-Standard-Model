# %% [markdown]
# # BHSM v2.6 Complete Operator Identification
#
# This notebook records the v2.6 audit result without changing frozen predictions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').joinpath('src').resolve()))
from complete_operator_identification_decision import build_complete_operator_identification_decision
build_complete_operator_identification_decision()

# %% [markdown]
# Final result: `STILL_BLOCKED_BY_SINGLE_NAMED_THEOREM_GAP`.
#
# Single blocking term: `lichnerowicz_bundle_curvature_remainder`.
#
# The theorem remains incomplete until this term is closed by an explicit complete-operator argument.
