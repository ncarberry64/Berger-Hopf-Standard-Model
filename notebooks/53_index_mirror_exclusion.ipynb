# %% [markdown]
# # BHSM v2.3 Index and Mirror Exclusion
#
# Executable audit notebook for the corrected formal-kernel index/mirror scaffold.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..', 'src').resolve()))
from topological_index_operator import build_topological_index_operator_report
from full_mirror_exclusion import build_full_mirror_exclusion_report
from index_mirror_closure_decision import build_index_mirror_closure_decision

# %%
topo = build_topological_index_operator_report()
mirror = build_full_mirror_exclusion_report()
decision = build_index_mirror_closure_decision()
topo, mirror, decision

# %% [markdown]
# ## Claim Discipline
#
# This notebook reports scaffold statuses only. It does not claim the full H_T or BHSM theorem is proven.
