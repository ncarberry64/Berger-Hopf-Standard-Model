# %% [markdown]
# # BHSM v1.3M — Formal-Kernel Regression and Convergence Audit
#
# This notebook reruns the finite-basis `H_T` regression and convergence checks using `DIRAC_PROXY_LEVEL_2_FORMAL_KERNEL`.
#
# Correct claim: BHSM v1.3M supersedes coordinate-first Level 2 conclusions where those depended on the old protected block. It does not prove the full `H_T` theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from formal_kernel_regression import build_formal_kernel_regression_report
from formal_kernel_convergence import build_formal_kernel_convergence_report

regression = build_formal_kernel_regression_report()
regression.lower_bound_rows

# %% [markdown]
# ## Sector-Coupling Regression

# %%
regression.sector_coupling_rows

# %% [markdown]
# ## Corrected Convergence Scan

# %%
convergence = build_formal_kernel_convergence_report()
convergence.classification, convergence.all_rows_pass, convergence.worst_direct_margin, convergence.worst_gershgorin_margin

# %%
convergence.rows

# %% [markdown]
# ## Limitation
#
# The corrected formal-kernel regression is finite-basis evidence. The full twisted Dirac / `H_T` theorem, topological index theorem, and infinite-basis complement split remain open.
