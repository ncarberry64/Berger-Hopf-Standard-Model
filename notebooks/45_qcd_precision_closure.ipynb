# %% [markdown]
# # BHSM Gate 3 — QCD/RG Precision Closure Attempt
#
# This notebook records the QCD/RG precision closure status. No precision-QCD reference values are invented.

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root / 'src'))
from qcd_precision_closure import build_qcd_precision_closure_report
report = build_qcd_precision_closure_report()
report.status, report.theorem_complete, report.final_precision_set_supplied

# %%
[(ref.name, ref.status, ref.placeholder, ref.final) for ref in report.matching_report.reference_sets]

# %% [markdown]
# Without supplied validated precision-QCD inputs, the correct status is `PRECISION_INPUTS_REQUIRED`.
