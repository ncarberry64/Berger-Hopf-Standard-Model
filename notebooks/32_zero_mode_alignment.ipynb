# %% [markdown]
# # BHSM v1.3J - Zero-Mode Alignment
#
# This notebook records the alignment audit between formal protected zero-mode labels and the finite Level 2 coordinate-protected block. It does not prove the full `H_T` theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from zero_mode_alignment import build_alignment_audit_report

report = build_alignment_audit_report()
report.one_to_one_alignment, report.open_alignment_gap_remains, report.theorem_complete

# %% [markdown]
# ## Formal Labels

# %%
[
    {
        "id": item.id,
        "sector": item.sector,
        "mode": (item.k, item.j, item.q),
        "chirality": item.chirality,
        "omega_value": item.omega_value,
        "omega_target": item.omega_target,
        "boundary_policy_status": item.boundary_policy_status,
    }
    for item in report.formal_labels
]

# %% [markdown]
# ## Coordinate-Protected Block

# %%
[
    {
        "index": item.coordinate_index,
        "sector": item.sector,
        "mode": (item.k, item.j, item.q),
        "chirality": item.chirality,
        "heat_lift_preserves": item.heat_lift_preserves,
        "sector_coupling_vanishes": item.sector_coupling_vanishes,
    }
    for item in report.coordinate_protected_states
]

# %% [markdown]
# ## Alignment Table

# %%
[
    {
        "formal": item.formal_label.id,
        "match_index": item.matching_coordinate_index,
        "coordinate_protected": item.matching_coordinate_protected,
        "heat_preserved": item.heat_lift_preserves_matching_state,
        "sector_coupling_vanishes": item.sector_coupling_vanishes_on_matching_state,
        "status": item.status,
    }
    for item in report.alignment_maps
]
