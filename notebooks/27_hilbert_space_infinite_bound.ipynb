# %% [markdown]
# # BHSM v1.3E - Hilbert-Space Infinite-Bound Scaffold
#
# This notebook records the Hilbert-space/domain assumptions under which the structured sector-coupling relative bound would extend beyond finite truncations. It does not prove the full `H_T` theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from hilbert_space_scaffold import build_hilbert_space_domain, build_operator_domains
from infinite_basis_bounds import build_infinite_bound_report

domain = build_hilbert_space_domain()
report = build_infinite_bound_report()
report.theorem.status, report.theorem_complete

# %% [markdown]
# ## Domain Summary

# %%
{
    "basis_label": domain.basis_label,
    "k_range": domain.k_range,
    "j_range_rule": domain.j_range_rule,
    "hopf_charge_rule": domain.hopf_charge_rule,
    "chiralities": domain.chiralities,
    "sectors": domain.sectors,
    "protected_zero_modes": domain.protected_zero_modes,
    "status": domain.status,
}

# %% [markdown]
# ## Operator Domains

# %%
[
    {
        "name": item.name,
        "expression": item.expression,
        "status": item.status,
        "domain": item.domain_definition,
    }
    for item in build_operator_domains()
]

# %% [markdown]
# ## Assumptions A1-A6

# %%
[
    {
        "id": assumption.id,
        "status": assumption.status,
        "statement": assumption.statement,
    }
    for assumption in report.theorem.assumptions
]

# %% [markdown]
# ## Conservative Candidate

# %%
report.conservative_candidate

# %% [markdown]
# ## Limitation
#
# `THEOREM_SCAFFOLD` is conditional. The finite evidence bridge remains separate from proof until A1-A6 and the zero-mode/complement split are derived from the complete operator.
