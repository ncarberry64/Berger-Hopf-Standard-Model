# %% [markdown]
# # BHSM v2.10 Mixed Connection Coefficients
#
# This notebook records the v2.10 mixed-connection coefficient audit without changing frozen predictions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').joinpath('src').resolve()))
from mixed_connection_closure_decision import build_mixed_connection_closure_decision
build_mixed_connection_closure_decision()

# %% [markdown]
# Final result: `STILL_BLOCKED_BY_SINGLE_NAMED_THEOREM_GAP`.
#
# Exact missing rule: `MIXED_HOPF_BASE_BOUNDARY_COFRAME_COEFFICIENT_RULE`.
#
# Exact remaining gap: `MIXED_CONNECTION_COEFFICIENT_RULE_GAP`.
