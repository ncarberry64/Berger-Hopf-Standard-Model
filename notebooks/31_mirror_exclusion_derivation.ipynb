# %% [markdown]
# # BHSM v1.3I - Mirror Exclusion Derivation
#
# This notebook records the mirror-exclusion channel audit. It does not prove the full `H_T` theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from mirror_exclusion_derivation import build_mirror_exclusion_report

report = build_mirror_exclusion_report()
report.excluded_count, report.open_mirror_risk_count, report.theorem_complete

# %% [markdown]
# ## Candidate Channel Table

# %%
[
    {
        "mirror": item.mirror_id,
        "sector": item.sector,
        "mode": (item.k, item.j, item.q),
        "chirality": item.mirror_chirality,
        "omega": item.omega_value,
        "chiral_projector": item.chiral_projector_result.status,
        "higgs_u1": item.higgs_u1_phase_result.status,
        "boundary_functional": item.boundary_functional_result.status,
        "final": item.final_classification,
        "channels": item.exclusion_channels,
    }
    for item in report.derivations
]

# %% [markdown]
# ## Claim Boundary
#
# The chiral projector channel excludes the generated opposite-chirality candidates in the scaffold. The full `H_T` theorem remains open until the topological index theorem, formal/coordinate zero-mode alignment, and infinite-basis complement bound are closed.
