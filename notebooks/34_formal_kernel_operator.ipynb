# %% [markdown]
# # BHSM v1.3L — Corrected Formal-Kernel Level 2 Operator
#
# This notebook audits the corrected Level 2 `H_T` scaffold variant that protects the formal sector-labeled kernel instead of the legacy coordinate-first block.
#
# Correct claim: BHSM v1.3L corrects the Level 2 `H_T` scaffold to protect the formal sector-labeled kernel. It does not prove the full no-extra-light-state theorem.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from formal_kernel_operator import operator_variant_summary
from level2_formal_kernel_ht import build_formal_kernel_correction_audit, legacy_vs_formal_gap_table, scan_formal_kernel_ht_gap

operator_variant_summary()

# %% [markdown]
# ## Corrected Gap Report

# %%
audit = build_formal_kernel_correction_audit()
audit.status, audit.ht_report

# %% [markdown]
# ## Legacy vs Formal-Kernel Comparison

# %%
legacy_vs_formal_gap_table()

# %% [markdown]
# ## Small Robustness Scan

# %%
scan_formal_kernel_ht_gap()

# %% [markdown]
# ## Limitation
#
# This remains a finite-basis Level 2 scaffold. The full twisted Dirac / `H_T` theorem, the full index theorem, and the infinite-basis complement split remain open.
