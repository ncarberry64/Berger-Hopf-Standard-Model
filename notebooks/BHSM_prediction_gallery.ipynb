# %% [markdown]
# # BHSM Prediction Gallery
# Gallery entries are status summaries, not empirical validation claims.
# Calibration stays calibration; speculative candidates are disabled by default.

# %%
from bhsm.interface import build_prediction_gallery
gallery = build_prediction_gallery()
gallery.to_dict()
