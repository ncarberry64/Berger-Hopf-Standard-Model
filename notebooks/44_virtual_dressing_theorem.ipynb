# %% [markdown]
# # BHSM Gate 2 — Virtual Dressing Closure Attempt
#
# This notebook records the closure attempt for `Z_virt^{u,2}=1/2`. The branch remains candidate-level.

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root / 'src'))
from virtual_dressing_theorem import build_virtual_dressing_theorem_report
report = build_virtual_dressing_theorem_report()
report.status, report.theorem_complete, report.changed_outputs

# %%
[(step.id, step.passes, step.evidence) for step in report.weak_projection_steps]

# %% [markdown]
# The structural weak-projection scaffold passes, but the full virtual loop/threshold derivation remains open.
