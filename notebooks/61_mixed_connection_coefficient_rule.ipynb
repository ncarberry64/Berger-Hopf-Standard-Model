# %% [markdown]
# # BHSM v2.11 Mixed Connection Coefficient Rule
#
# This notebook records the v2.11 axiom-driven mixed coefficient rule audit.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..', 'src').resolve()))
from mixed_coefficient_rule import build_mixed_coefficient_rule_report
from mixed_coefficient_rule_decision import build_mixed_coefficient_rule_decision
from mixed_connection_closure_decision import build_mixed_connection_closure_decision

# %%
rule = build_mixed_coefficient_rule_report()
decision = build_mixed_coefficient_rule_decision()
closure = build_mixed_connection_closure_decision()
rule.rule_status, decision.final_result, closure.mixed_connection_classification
