# %% [markdown]
# # BHSM v1.4 -- QCD/RG Matching Scaffold
#
# This notebook records the scheme-aware comparison scaffolds. It does not change BHSM predictions or implement precision QCD.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from qcd_rg_matching import build_qcd_rg_matching_report
report = build_qcd_rg_matching_report()
report.title, report.stop_condition_triggered, report.theorem_complete

# %% [markdown]
# ## Reference Sets

# %%
[(name, data['status'], data['scheme_consistent'], data['comparison_final']) for name, data in report.reference_sets.items()]

# %% [markdown]
# ## Quark Ratio Comparison Rows

# %%
[(row.branch, row.quantity, row.predicted, row.reference, row.relative_error, row.scheme_set, row.status) for row in report.comparison_rows]
