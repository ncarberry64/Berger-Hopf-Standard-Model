# %% [markdown]
# # BHSM v2.9 Complete Bundle Connection Curvature
#
# This notebook records the v2.9 connection-curvature audit without changing frozen predictions.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').joinpath('src').resolve()))
from bundle_curvature_closure_decision import build_bundle_curvature_closure_decision
build_bundle_curvature_closure_decision()

# %% [markdown]
# Final result: `STILL_BLOCKED_BY_SINGLE_NAMED_THEOREM_GAP`.
#
# Exact missing component: `mixed_hopf_base_boundary_coframe_connection`.
#
# Exact remaining gap: `MIXED_HOPF_BASE_BOUNDARY_COFRAME_CONNECTION_GAP`.
