# %% [markdown]
# # BHSM CLI Review Walkthrough
# Live PDG values are comparison references only and are never BHSM derivation inputs.
# Runtime-disabled software gates require external validation.

# %%
from bhsm.interface import default_prediction_registry, build_prediction_report
registry = default_prediction_registry()
report = build_prediction_report(include_open_theorem_entries=True)
report.to_dict()
