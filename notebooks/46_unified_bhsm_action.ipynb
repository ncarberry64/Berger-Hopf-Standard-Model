# %% [markdown]
# # BHSM Gate 4 — Unified Action Closure
#
# This notebook records the unified dependency graph. It has open theorem nodes.

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root / 'src'))
from action_dependency_closure import build_action_dependency_closure_report
report = build_action_dependency_closure_report()
report.status, report.theorem_complete, report.open_nodes

# %%
report.gate_statuses
